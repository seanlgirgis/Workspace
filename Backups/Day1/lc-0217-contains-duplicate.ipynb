# %% [markdown]
# # 🧠 LeetCode 217: Contains Duplicate
#
# **Pattern:** Hash Set
#
# - **Created:** 2026-02-28
# - **Focus:** Checking for existence optimally
# - **Tags:** `array` | `hash-table` | `easy` | `citi-prep`

# %% [markdown]
# ## 📖 Problem Statement
#
# Given an integer array `nums`, return `true` if any value appears at least twice in the array, and return `false` if every element is distinct.
#
# ### Example 1:
# - **Input:** `nums = [1,2,3,1]`
# - **Output:** `true`
#
# ### Example 2:
# - **Input:** `nums = [1,2,3,4]`
# - **Output:** `false`

# %% [markdown]
# ## 🧠 Mental Model & Intuition
#
# Imagine guarding a nightclub entrance holding a clipboard. You only allow unique people inside.
#
# Every time someone arrives, you check the clipboard. If their name is already written down, you've found a duplicate! If not, you write their name down.
#
# In Python, that clipboard is a `set()`. Checking a `set` is nearly instant $O(1)$ compared to checking a list $O(N)$.

# %% [markdown]
# ## 🐢 Brute Force Approach
#
# Check every item against every other item.
#
# ```python
# def containsDuplicateBrute(nums):
#     for i in range(len(nums)):
#         for j in range(i + 1, len(nums)):
#             if nums[i] == nums[j]:
#                 return True
#     return False
# ```
# **Time:** $O(N^2)$ (Causes Timeout on LeetCode) | **Space:** $O(1)$

# %%
# The optimal "Clipboard" approach
def containsDuplicate(nums: list[int]) -> bool:
    hashset = set()
    
    for num in nums:
        if num in hashset:
            return True
        hashset.add(num)
        
    return False

# Alternative (Pythonic but doesn't show iteration logic as clearly to an interviewer):
# def containsDuplicate(nums):
#     return len(set(nums)) != len(nums)

# Tests
print(containsDuplicate([1, 2, 3, 1]))  # True
print(containsDuplicate([1, 2, 3, 4]))  # False

# %% [markdown]
# ## ⏱️ Complexity Analysis
#
# - **Time Complexity:** $O(N)$ because checking `if num in hashset` is $O(1)$, and we loop $N$ times worst-case.
# - **Space Complexity:** $O(N)$ because the `hashset` can grow to store all $N$ elements if they are unique.

# %% [markdown]
# ## 🎤 Interview Q&A
#
# ### Q1: What trade-off are you making by using a Hash Set?
# **Answer:** We are trading memory for speed. We reduce the Time Complexity from $O(N^2)$ to $O(N)$ by increasing Space Complexity from $O(1)$ to $O(N)$.
#
# ---
#
# ### Q2: What if we can't use extra memory (Space strictly $O(1)$)?
# **Answer:** If we are constrained to $O(1)$ space, we could sort the array in-place first (assuming `nums.sort()` uses $O(1)$ auxiliary space, though in many languages it's actually $O(\log N)$). Then we just loop through once and check if the adjacent elements are identical (`nums[i] == nums[i+1]`). The time would degrade to $O(N \log N)$ due to sorting.

# %% [markdown]
# ## 📚 Key Terminology
#
# | Term | Definition | Example |
# |---|---|---|
# | **Hash Set** | A collection of unique elements with $O(1)$ average time complexity for lookups, insertions, and deletions. | `Python set()` |
# | **Hash Map** | Stores Key-Value pairs. | `Python dict()` |
# | **In-place** | An algorithm that does not need extra data structures proportional to input size. | Sorting the original array. |

# %% [markdown]
# ## 💼 The Citi Narrative
#
# **Context:** Server Inventory Check.
#
# **Scenario:** During migrations, we often merged server inventory lists from North America and EMEA. We had to immediately flag if a `Hostname` appeared twice, as it indicated a DNS conflict or a duplicated record.
#
# **Impact:** Doing an `IN` check against a Python List containing 30,000 servers took minutes. Converting the list of already-migrated servers into a `set()` made the uniqueness validation instantaneous. A core engineering principle is: If you need to repeatedly ask "does this exist?", use a Hash Set.

# %%
# EXERCISE: Implement the adjacent checking solution (O(1) Space, O(N log N) Time)

def containsDuplicateSorted(nums: list[int]) -> bool:
    # Sort the array in place
    nums.sort()
    
    # Check adjacent pairs
    for i in range(len(nums) - 1):
        if nums[i] == nums[i+1]:
            return True
    return False

print(containsDuplicateSorted([4, 1, 3, 4, 2]))

# %% [markdown]
# ## 🎯 Summary: Key Takeaways
#
# ### The Pattern
# **Hash Set** — Tracking uniqueness by inserting elements into a constant-time lookup set.
#
# ### When to Use It
# - ✅ Quick deduplication of streaming data.
# - ✅ Detecting cyclical patterns or repeated states.
# - ❌ **Don't use when:** Need to count exact frequencies (Use Hash Map instead).
#
# ### Complexity
# | Approach | Time | Space |
# |----------|------|-------|
# | Brute Force | $O(N^2)$ | $O(1)$ |
# | Optimal | $O(N)$ | $O(N)$ |
#
# ### Interview Confidence Checklist
# - [ ] Can explain the brute force and why it fails
# - [ ] Can state the pattern name and core insight in one sentence
# - [ ] Can write the optimal solution from memory
# - [ ] Can state time and space complexity with justification
# - [ ] Can name at least one real-world / Citi application

# %% [markdown]
# ---
#
# **"Simplicity and clarity is Gold."** — Sean's Study Mantra
#
# Master **Hash Set** and you've mastered one of the most common patterns in data engineering interviews. 🚀
