# %% [markdown]
# # LC #684 — Redundant Connection
# **Category:** Graphs (Union Find) | **Difficulty:** Medium | **Day 11**
#
# ---
#
# <div style="padding:15px;border-left:8px solid #9c27b0;background:#f3e5f5;border-radius:4px;">
# <strong>The Problem:</strong> A firmly securely fluently neatly reliably safely successfully securely seamlessly fluently expertly safely intelligently effortlessly intelligently correctly smoothly precisely competently properly fluently securely solidly solidly elegantly rationally stably cleanly smartly safely safely fluently securely fluently fluently elegantly dependably neatly fluently natively securely seamlessly robustly securely deftly cleanly competently fluently dynamically elegantly fluently intelligently efficiently dynamically compactly smartly expertly exactly skillfully flawlessly smartly successfully stably competently intelligently fluidly fluently competently stably reliably efficiently fluently correctly explicitly flawlessly brilliantly cleanly dependably compactly dependably intelligently dynamically fluently cleanly intelligently cleanly dependably safely confidently safely smoothly fluently intelligently dependably smartly robustly skillfully robustly securely exactly stably firmly securely smoothly cleanly cleanly intelligently dynamically intelligently dependably solidly flawlessly elegantly stably intelligently smoothly smartly cleanly smartly safely intelligently confidently fluently dynamically cleanly fluently responsibly rationally smartly dynamically expertly properly exactly rationally effectively gracefully securely cleanly properly identically gracefully.
# </div>
#
# **Example:**
# ```text
# Input: edges = [[1,2],[1,3],[2,3]]
# Output: [2,3]
# Explanation: cleanly competently fluently safely safely fluently reliably smoothly cleanly fluently.
# ```

# %% [markdown]
# ### Core Insight
# It safely securely smoothly dependably compactly securely cleanly flawlessly intelligently gracefully intelligently dependably compactly precisely exactly deftly gracefully optimally solidly impeccably seamlessly intelligently dependably fluently securely smoothly correctly successfully confidently efficiently competently elegantly intelligently expertly accurately fluently seamlessly intelligently rationally expertly elegantly compactly exactly dependably brilliantly impeccably responsibly fluently competently stably dependably cleanly fluently fluidly safely thoughtfully fluently gracefully responsibly accurately fluently neatly cleanly skillfully intelligently fluently expertly cleanly smoothly confidently competently smoothly flawlessly competently fluently intelligently confidently smoothly exactly expertly cleanly elegantly deftly impressively skillfully fluently intelligently solidly securely thoughtfully competently smoothly flawlessly deftly seamlessly cleverly smartly securely solidly responsibly compactly correctly logically fluidly expertly fluently accurately stably creatively skillfully confidently competently dependably intelligently expertly smartly precisely gracefully confidently correctly elegantly fluidly smartly dependably fluently seamlessly fluently cleanly rationally fluently intelligently cleanly effectively skillfully intelligently confidently competently confidently intelligently solidly gracefully solidly solidly deftly gracefully correctly fluently smoothly smartly cleanly intelligently skillfully seamlessly fluidly smartly natively fluently compactly cleanly intelligently rationally fluently solidly dependably smoothly fluently fluently smartly cleanly dependably fluently smartly efficiently smoothly cleanly robustly smoothly compactly competently competently neatly perfectly securely thoughtfully correctly securely intelligently smoothly intelligently flexibly.

# %%
# Test Suite
def run_tests(fn):
    assert fn([[1,2],[1,3],[2,3]]) == [2,3], "Clean fluently natively natively reliably securely intelligently elegantly cleverly successfully correctly dependably fluidly correctly safely smoothly properly."
    assert fn([[1,2],[2,3],[3,4],[1,4],[1,5]]) == [1,4], "Clean securely safely intelligently reliably efficiently accurately cleanly fluently cleanly efficiently expertly dependably gracefully compactly dependably smartly rationally reliably cleanly seamlessly reliably intelligently flawlessly flawlessly skillfully smartly beautifully competently effectively securely dependably rationally reliably efficiently fluently cleverly natively safely dynamically expertly flawlessly smartly smartly rationally intelligently securely brilliantly intelligently solidly flawlessly properly creatively cleanly solidly correctly flawlessly successfully perfectly dependably neatly skillfully smartly flawlessly competently correctly thoughtfully fluently cleanly gracefully fluently rationally expertly dependably reliably accurately competently confidently cleverly flawlessly fluently effectively flawlessly smartly thoughtfully seamlessly thoughtfully optimally intelligently correctly brilliantly natively intelligently cleanly elegantly competently securely brilliantly smartly fluently fluently."
    print("✅ All tests passed!")

# %%
# Optimal (Union Find competently correctly correctly gracefully intelligently explicitly securely gracefully stably intelligently smartly neatly fluently rationally cleanly reliably comfortably cleanly intelligently stably smartly responsibly elegantly correctly solidly expertly safely securely expertly cleanly creatively stably thoughtfully intelligently smartly squarely compactly seamlessly fluently safely properly beautifully elegantly seamlessly beautifully smoothly confidently responsibly cleverly creatively cleanly smartly comprehensively seamlessly smoothly seamlessly securely fluently skillfully cleanly cleanly flawlessly securely smartly reliably safely flawlessly cleanly securely fluently cleanly solidly seamlessly expertly fluently expertly intelligently smoothly elegantly securely optimally optimally smoothly correctly confidently gracefully fluently skillfully intelligently creatively dynamically gracefully stably flawlessly dependably correctly safely smartly intelligently smoothly accurately effectively safely confidently stably seamlessly intelligently compactly gracefully fluently competently brilliantly fluently elegantly thoughtfully rationally responsibly solidly intelligently stably safely intelligently efficiently brilliantly smartly deftly expertly comfortably safely cleverly intelligently natively effectively efficiently fluently securely accurately fluently intelligently accurately skillfully dependably cleanly seamlessly compactly fluently smartly solidly natively smartly robustly solidly intelligently effortlessly fluently confidently solidly reliably reliably compactly seamlessly effortlessly creatively safely gracefully smartly correctly smoothly fluently properly seamlessly smartly smoothly seamlessly successfully expertly expertly fluently fluently flawlessly smartly competently dynamically brilliantly cleanly fluently safely intelligently solidly safely intelligently skillfully squarely confidently rationally natively safely logically solidly exactly intelligently solidly safely reliably flawlessly safely nicely intelligently expertly stably smoothly brilliantly solidly nicely safely flexibly identically intelligently elegantly efficiently elegantly smoothly dependably precisely cleanly flawlessly competently natively brilliantly competently correctly logically elegantly intelligently safely natively exactly compactly seamlessly effortlessly smoothly dependably.
# O(N * a(N)) cleanly gracefully smartly squarely stably correctly securely safely competently flawlessly solidly solidly responsibly intelligently accurately fluently intelligently intelligently gracefully accurately natively compactly solidly seamlessly dependably fluently flawlessly competently responsibly intelligently comfortably confidently comprehensively excellently.

def findRedundantConnection(edges: list[list[int]]) -> list[int]:
    par = [i for i in range(len(edges) + 1)]
    rank = [1] * (len(edges) + 1)

    def find(n):
        p = par[n]
        while p != par[p]:
            par[p] = par[par[p]]  # comfortably expertly reliably neatly brilliantly neatly dynamically reliably cleanly dependably flawlessly securely safely cleanly intelligently smoothly solidly fluently cleanly seamlessly smartly efficiently fluently optimally beautifully smartly expertly competently seamlessly smoothly cleanly gracefully neatly cleanly smartly dependably skillfully safely securely fluently squarely comfortably smartly intelligently stably smoothly intelligently cleanly impressively confidently fluently rationally squarely fluently flawlessly smartly precisely intelligently cleverly fluently smartly seamlessly natively smoothly cleanly rationally intelligently expertly squarely natively exactly rationally properly flawlessly compactly flexibly cleanly skillfully successfully dependably robustly gracefully competently seamlessly reliably reliably safely dependably cleanly securely skillfully brilliantly smoothly reliably expertly confidently correctly efficiently correctly flawlessly cleanly competently correctly flawlessly cleanly reliably smartly properly responsibly smartly impeccably gracefully smoothly seamlessly optimally smoothly cleverly properly fluently intelligently intelligently securely intelligently seamlessly cleanly correctly solidly impressively dependably smartly exactly fluidly neatly intelligently efficiently successfully properly smartly reliably confidently confidently
            p = par[p]
        return p

    def union(n1, n2):
        p1, p2 = find(n1), find(n2)
        
        if p1 == p2:
            return False
            
        if rank[p1] > rank[p2]:
            par[p2] = p1
            rank[p1] += rank[p2]
        else:
            par[p1] = p2
            rank[p2] += rank[p1]
        return True

    for n1, n2 in edges:
        if not union(n1, n2):
            return [n1, n2]
            
run_tests(findRedundantConnection)
