# %% [markdown]
# ## 🏗️ LeetCode {{PROBLEM_NUMBER}}: {{PROBLEM_TITLE}}
# ---
#
# <div style="padding: 15px; border-left: 8px solid {{ACCENT_COLOR}}; background-color: {{BG_COLOR}}; color: {{TEXT_COLOR}}; border-radius: 4px;">
#     <strong>The Core Insight:</strong> {{CORE_INSIGHT}}
# </div>
#
# ### 🛠️ The Mathematical Model
#
# {{MATH_MODEL_DESCRIPTION}}
#
# $${{LATEX_FORMULA}}$$
#
# ---
#
# ### 📋 Problem
#
# {{PROBLEM_STATEMENT}}
#
# **Example 1:**
# ```
# Input:  {{EXAMPLE_1_INPUT}}
# Output: {{EXAMPLE_1_OUTPUT}}
# ```
#
# **Example 2:**
# ```
# Input:  {{EXAMPLE_2_INPUT}}
# Output: {{EXAMPLE_2_OUTPUT}}
# ```
#
# **Constraints:** {{CONSTRAINTS}}

# %% [markdown]
# ### 🧠 Choose Your Mental Model
#
# <table style="width:100%; border-collapse: collapse;">
#     <tr style="background-color: #f2f2f2; text-align: left;">
#         <th style="padding: 12px; border: 1px solid #ddd;">Model</th>
#         <th style="padding: 12px; border: 1px solid #ddd;">The "Story"</th>
#         <th style="padding: 12px; border: 1px solid #ddd;">Mechanism</th>
#     </tr>
#     <tr>
#         <td style="padding: 12px; border: 1px solid #ddd;"><b>{{MODEL_1_NAME}}</b></td>
#         <td style="padding: 12px; border: 1px solid #ddd;">"{{MODEL_1_STORY}}"</td>
#         <td style="padding: 12px; border: 1px solid #ddd;">{{MODEL_1_MECHANISM}}</td>
#     </tr>
#     <tr>
#         <td style="padding: 12px; border: 1px solid #ddd;"><b>{{MODEL_2_NAME}}</b></td>
#         <td style="padding: 12px; border: 1px solid #ddd;">"{{MODEL_2_STORY}}"</td>
#         <td style="padding: 12px; border: 1px solid #ddd;">{{MODEL_2_MECHANISM}}</td>
#     </tr>
# </table>

# %% [markdown]
# ---
#
# ### ⚠️ Performance Warning
#
# <div style="padding: 10px; border: 1px solid #ffe58f; background-color: #fffbe6; border-radius: 4px;">
#     <strong>Note:</strong> {{BRUTE_FORCE_WARNING}}
# </div>
#
# ## 🐢 Approach 1: Brute Force — $O({{BRUTE_TIME_COMPLEXITY}})$

# %%
def {{FUNCTION_NAME}}_brute({{FUNCTION_PARAMS}}):
    """
    Brute Force: {{BRUTE_DESCRIPTION}}
    Time: O({{BRUTE_TIME}}) | Space: O({{BRUTE_SPACE}})
    """
    {{BRUTE_CODE}}


# Test Cases
print({{FUNCTION_NAME}}_brute({{TEST_1_INPUT}}))  # Expected: {{TEST_1_EXPECTED}}
print({{FUNCTION_NAME}}_brute({{TEST_2_INPUT}}))  # Expected: {{TEST_2_EXPECTED}}

# %% [markdown]
# ## 🔬 Complexity Analysis: $O({{BRUTE_TIME}})$ vs. $O({{OPTIMAL_TIME}})$
#
# <div style="padding: 15px; border-left: 8px solid #2196F3; background-color: #f0f7ff; color: #0d47a1; border-radius: 4px;">
#     <strong>The Core Insight:</strong> {{COMPLEXITY_INSIGHT}}
# </div>
#
# ---
#
# ## 📉 Why Brute Force Fails: The $O({{BRUTE_TIME}})$ Trap
#
# {{BRUTE_FAILURE_EXPLANATION}}
#
# $${{BRUTE_MATH}}$$
#
# | Input Type | Brute Force Performance | Reason |
# |------------|------------------------|--------|
# | **{{CASE_1_NAME}}** | {{CASE_1_PERF}} | {{CASE_1_REASON}} |
# | **{{CASE_2_NAME}}** | {{CASE_2_PERF}} | {{CASE_2_REASON}} |
#
# ---
#
# ## 🚀 The Optimal Approach: $O({{OPTIMAL_TIME}})$
#
# {{OPTIMAL_EXPLANATION}}
#
# ### The Key Lifecycle Rule
# 1. **{{LIFECYCLE_STEP_1}}**
# 2. **{{LIFECYCLE_STEP_2}}**
#
# ---
#
# ## ✅ Mathematical Proof
#
# $${{PROOF_MATH}}$$
#
# <div style="padding: 10px; border-left: 8px solid #4CAF50; background-color: #f1f8f4; color: #1b5e20; border-radius: 4px;">
#     <strong>✅ Summary:</strong> {{PROOF_SUMMARY}}
# </div>

# %% [markdown]
# ## 🚀 Approach 2: {{OPTIMAL_APPROACH_NAME}} — $O({{OPTIMAL_TIME}})$
# ---
#
# Instead of {{WHAT_BRUTE_DOES}}, we use **{{DATA_STRUCTURE}}** as a {{DATA_STRUCTURE_ROLE}}.
#
# As we iterate:
# 1. {{ALGORITHM_STEP_1}}
# 2. {{ALGORITHM_STEP_2}}
# 3. {{ALGORITHM_STEP_3}}

# %%
def {{FUNCTION_NAME}}_optimized({{FUNCTION_PARAMS}}):
    """
    Optimal: {{OPTIMAL_APPROACH_NAME}}
    Time: O({{OPTIMAL_TIME}}) | Space: O({{OPTIMAL_SPACE}})
    """
    {{OPTIMAL_CODE}}


print("Optimal:", {{FUNCTION_NAME}}_optimized({{TEST_1_INPUT}}))  # Expected: {{TEST_1_EXPECTED}}
print("Optimal:", {{FUNCTION_NAME}}_optimized({{TEST_2_INPUT}}))  # Expected: {{TEST_2_EXPECTED}}

# %% [markdown]
# ## 🎤 5 Interview Q&A
#
# ### Q1: {{Q1}}
#
# **Answer:** {{A1}}
#
# ---
#
# ### Q2: {{Q2}}
#
# **Answer:** {{A2}}
#
# ---
#
# ### Q3: What is the time complexity of the optimal approach and why?
#
# **Answer:** $O({{OPTIMAL_TIME}})$. {{COMPLEXITY_EXPLANATION}}
#
# ---
#
# ### Q4: {{Q4}}
#
# **Answer:** {{A4}}
#
# ---
#
# ### Q5: What are the edge cases to watch for?
#
# **Answer:** {{EDGE_CASES}}

# %% [markdown]
# ## 📚 Key Terminology
#
# | Term | Definition |
# |------|------------|
# | **{{TERM_1}}** | {{TERM_1_DEF}} |
# | **{{TERM_2}}** | {{TERM_2_DEF}} |
# | **{{TERM_3}}** | {{TERM_3_DEF}} |
# | **{{TERM_4}}** | {{TERM_4_DEF}} |
# | **{{TERM_5}}** | {{TERM_5_DEF}} |

# %% [markdown]
# ## 💼 The Citi Narrative
#
# **Context:** {{CITI_CONTEXT}}
#
# **Scenario:** {{CITI_SCENARIO}}
#
# **How this pattern applied:** {{CITI_PATTERN_CONNECTION}}
#
# **Impact:** {{CITI_IMPACT}}

# %%
# -------------------------------------------------------
# PRACTICE: Solve this variant without looking above
# {{PRACTICE_VARIANT_DESCRIPTION}}
# -------------------------------------------------------

def {{FUNCTION_NAME}}_practice({{FUNCTION_PARAMS}}):
    # Your solution here
    pass


# Test
print({{FUNCTION_NAME}}_practice({{TEST_1_INPUT}}))  # Expected: {{TEST_1_EXPECTED}}

# %% [markdown]
# ## 🎯 Summary: Key Takeaways
#
# ### The Pattern
# **{{PATTERN_NAME}}** — {{PATTERN_ONE_LINE_DESCRIPTION}}
#
# ### When to Use It
# - ✅ {{USE_CASE_1}}
# - ✅ {{USE_CASE_2}}
# - ❌ **Don't use when:** {{WHEN_NOT_TO_USE}}
#
# ### Complexity
# | Approach | Time | Space |
# |----------|------|-------|
# | Brute Force | $O({{BRUTE_TIME}})$ | $O({{BRUTE_SPACE}})$ |
# | Optimal ({{OPTIMAL_APPROACH_NAME}}) | $O({{OPTIMAL_TIME}})$ | $O({{OPTIMAL_SPACE}})$ |
#
# ### Interview Confidence Checklist
# - [ ] Can explain the brute force and why it fails
# - [ ] Can state the pattern name and core insight in one sentence
# - [ ] Can write the optimal solution from memory
# - [ ] Can state time and space complexity with justification
# - [ ] Can name at least one real-world / Citi application

# %% [markdown]
# ---
#
# **"Simplicity and clarity is Gold."** — Sean's Study Mantra
#
# Master {{PATTERN_NAME}} and you've mastered one of the most common patterns in data engineering interviews. 🚀
